# %% [markdown]
# Realizando o download do dataset:

# %%
import gdown
import os
import pandas as pd

id_da_pasta = '1h9cDrlc3Y-eUHJsikezlWNYYBTkDD9Um'

pasta_destino = '../dados/'

os.makedirs(pasta_destino, exist_ok=True)

print("Fazendo download do dataset... Aguarde.")

gdown.download_folder(id=id_da_pasta, output=pasta_destino, quiet=True, use_cookies=False)

print("\nDownload concluído")
# Out:
# Fazendo download do dataset... Aguarde.
# Retrieving folder contents
# Retrieving folder 15UaOCkuv3nrNiEuEcTNg8iTKft7QbpT0 dashboard_subsidio_sppo
# Retrieving folder 1aSzmCAaX45BmuQZN2p4Y4DWfnD1w4A-i dashboard_subsidio_sppo
# Processing file 1fGu2W-08v1l45TeTDyGbE2Gqv8etDRli dicionario.csv
# Processing file 1djPYc8RZJtmNjXnYF9DUS1lRQy4vnw6T subsidio_parametros.csv
# Processing file 126Y7MwwiWANyOpmMNgNOL1FkVtj_YeEN sumario_dia.csv
# Processing file 1EijywEWEo96LSTFaafyYc4Xv2w4I7S4F sumario_servico_dia.csv
# Processing file 1NgCMq3hzPMuM5KrdlrDVXkWPtTA6Jfhn sumario_servico_dia_historico.csv
# Processing file 1sbe-2PshZrGzVobYvQNdTyPEDRgVB8H5 sumario_servico_dia_tipo.csv
# Retrieving folder 1Y-M50diBamugEa1YiTD-Xw8Esw-55Tfc gtfs
# Processing file 1fER3VZ9Ju735UkY2lmrxaG5PsJKG0_t- agency.csv
# Processing file 1YXZPAKNhRWVcyz3YaYEZ7ma9W1zgywDm calendar.csv
# Processing file 1AW37eKfCHX3q2hoYXW3M2J5Hge5oXSaN calendar_dates.csv
# ...
